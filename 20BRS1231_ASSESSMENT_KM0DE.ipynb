# %% [markdown]
# <a href="https://colab.research.google.com/github/harishkumar77/ML_20BRS1231/blob/main/20BRS1231_ASSESSMENT_KM0DE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs as data
from sklearn.cluster import KMeans

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
# !pip install kmodes
from kmodes.kmodes import KModes
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
data = pd.read_csv('/content/kmodes.csv')
data.head(5)
# Out:
#   Person hair color eye color skin color
# 0     p1     blonde     amber       fair
# 1     p2   brunette      gray      brown
# 2     p3        red     green      brown
# 3     p4      black     hazel      brown
# 4     p5   brunette     amber       fair

# %%
# Elbow curve to find optimal K
cost = []
K = range(1,5)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(data)
    cost.append(kmode.cost_)
    
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 22.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 22.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 22.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 22.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 22.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1, cost: 15.0
# Run 1, iteration: 2/100, moves: 1, cost: 15.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# ...

# %%
# Building the model with 3 clusters
kmode = KModes(n_clusters=3, init = "random", n_init = 5, verbose=1)
clusters = kmode.fit_predict(data)
clusters
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 12.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2, cost: 11.0
# Run 2, iteration: 2/100, moves: 0, cost: 11.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 11.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 15.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1, cost: 12.0
# Run 5, iteration: 2/100, moves: 1, cost: 12.0
# Best run was number 2
# array([2, 0, 1, 0, 2, 0, 1, 0], dtype=uint16)

# %%
data.insert(0, "Cluster", clusters, True)
data
# Out:
#    Cluster Person hair color eye color skin color
# 0        2     p1     blonde     amber       fair
# 1        0     p2   brunette      gray      brown
# 2        1     p3        red     green      brown
# 3        0     p4      black     hazel      brown
# 4        2     p5   brunette     amber       fair
# 5        0     p6      black      gray      brown
# 6        1     p7        red     green       fair
# 7        0     p8      black     hazel       fair
