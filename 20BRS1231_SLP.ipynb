# %% [markdown]
# <a href="https://colab.research.google.com/github/harishkumar77/ML_20BRS1231/blob/main/20BRS1231_SLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/data.csv')
data.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data['diagnosis'].replace({'M':1,'B':0}, inplace = True)
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
X = data['fractal_dimension_worst']
y = data.drop(['fractal_dimension_worst'],axis=1)

# %%
X
# Out:
# 0      0.11890
# 1      0.08902
# 2      0.08758
# 3      0.17300
# 4      0.07678
#         ...
# 564    0.07115
# 565    0.06637
# 566    0.07820
# 567    0.12400
# 568    0.07039
# Name: fractal_dimension_worst, Length: 569, dtype: float64

# %%
y
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
y = np.nan_to_num(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
len(X_train)
# Out:
# 381

# %%
import tensorflow

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Activation, Dense 
import tensorflow.keras as tfk
model = Sequential() 
initializer=tfk.initializers.Ones()
layer_1 = Dense(1, input_shape = (1,),kernel_initializer=initializer,bias_initializer=initializer) 
# layer2=Dense(1)
model.add(layer_1) 
# model.add(layer2)
opt = tfk.optimizers.Adam(learning_rate=0.01)
model.compile(loss=tensorflow.keras.losses.MeanSquaredError(),optimizer=opt)

# %%
history=model.fit(X_train,y_train,epochs=50,batch_size=8)
# Out:
# Epoch 1/50
# 48/48 [==============================] - 0s 1ms/step - loss: 553884854517760.0000
# Epoch 2/50
# 48/48 [==============================] - 0s 1ms/step - loss: 553884787408896.0000
# Epoch 3/50
# 48/48 [==============================] - 0s 1ms/step - loss: 553884720300032.0000
# Epoch 4/50
# 48/48 [==============================] - 0s 2ms/step - loss: 553884888072192.0000
# Epoch 5/50
# 48/48 [==============================] - 0s 1ms/step - loss: 553884787408896.0000
# Epoch 6/50
# 48/48 [==============================] - 0s 1ms/step - loss: 553884854517760.0000
# Epoch 7/50
# 48/48 [==============================] - 0s 1ms/step - loss: 553884787408896.0000
# Epoch 8/50
# 48/48 [==============================] - 0s 1ms/step - loss: 553884854517760.0000
# Epoch 9/50
# 48/48 [==============================] - 0s 2ms/step - loss: 553884753854464.0000
# Epoch 10/50
# 48/48 [==============================] - 0s 2ms/step - loss: 553884854517760.0000
# Epoch 11/50
# ...

# %%
import matplotlib.pyplot as plt

# %%
y_pred = model.predict(X_test).sum(axis=1)
# Out:
# 6/6 [==============================] - 0s 2ms/step

# %%
len(y_test)
# Out:
# 188

# %%
len(y_pred)
# Out:
# 188

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
r2_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-208-4b2a19238fcd> in <module>
#       1 from sklearn.metrics import r2_score
#       2 from sklearn.metrics import mean_squared_error
# ----> 3 r2_score(y_test, y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     788     """
#     789     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 790         y_true, y_pred, multioutput
#     791     )
#     792     check_consistent_length(y_true, y_pred, sample_weight)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     105         raise ValueError(
#     106             "y_true and y_pred have different number of output ({0}!={1})".format(
# ...
